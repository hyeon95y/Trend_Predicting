# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os

# %%
#데이터가져오기
Product = pd.read_csv("C:/Users/lsh93/Desktop/data/Product.csv")
Search1 = pd.read_csv("C:/Users/lsh93/Desktop/data/Search1.csv")
Search2 = pd.read_csv("C:/Users/lsh93/Desktop/data/Search2.csv")
Custom = pd.read_csv("C:/Users/lsh93/Desktop/data/Custom.csv")
Session = pd.read_csv("C:/Users/lsh93/Desktop/data/Session.csv")
Master = pd.read_csv("C:/Users/lsh93/Desktop/data/Master.csv")
# Out:
# C:\Users\lsh93\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#1. Custom_Product_Master 
#연령대별로 구매한 상품 브랜드의 트렌드
Product_Master = pd.merge(Product,Master)

# %%
Product_Master.head()
# Out:
#    CLNT_ID  SESS_ID  HITS_SEQ    PD_C     PD_ADD_NM PD_BRA_NM PD_BUY_AM  \
# 0  4139680  7605037        12  642112       색상:워터멜론   [바비브라운]    39,000
# 1  4350334  2023661        77  642112    색상:엔젤 / 1개     바비브라운    39,000
# 2  5172356  4714565        47  642112        색상:카바나   [바비브라운]    39,000
# 3  5444959  6843465        24  642112  색상:워터멜론 / 1개     바비브라운    39,000
# 4  5461276  7896792        53  642112  색상:워터멜론 / 1개     바비브라운    39,000
#
#   PD_BUY_CT          PD_NM  CLAC1_NM CLAC2_NM       CLAC3_NM
# 0         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터
# 1         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터
# 2         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터
# 3         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터
# 4         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터

# %%
Custom_Product_Master = pd.merge(Custom, Product_Master)

# %%
Custom_Product_Master.head()
# Out:
#    CLNT_ID CLNT_GENDER  CLNT_AGE  SESS_ID  HITS_SEQ    PD_C  \
# 0  4830726           F        30  2546785        45  357970
# 1  4830726           F        30  2546785        27  357970
# 2  4830874           F        40  1456881        35   81976
# 3  4830874           F        40  1456881        35   81976
# 4  4830874           F        40  1456881        35   81976
#
#                        PD_ADD_NM   PD_BRA_NM PD_BUY_AM PD_BUY_CT  \
# 0                             1개  에스까다(선글라스)   130,000         1
# 1                             1개  에스까다(선글라스)   130,000         1
# 2   색상:버건디(90)|사이즈:S(90/66) / 1개          유닛    69,000         1
# 3  색상:아이보리(41)|사이즈:S(90/66) / 1개          유닛    69,000         1
# 4  색상:D/그린(04)|사이즈:S(90/66) / 1개          유닛    69,000         1
#
#                                                PD_NM CLAC1_NM CLAC2_NM  \
# 0                                SES937G 531X SES937     패션잡화  안경/선글라스
# 1                                SES937G 531X SES937     패션잡화  안경/선글라스
# 2  [UFC4-KT42N]캐시미어100프로 기본 터틀넥 니트 스웨터 - L/블루(15)...     여성의류   여성의류상의
# 3  [UFC4-KT42N]캐시미어100프로 기본 터틀넥 니트 스웨터 - L/블루(15)...     여성의류   여성의류상의
# 3988584  3661917           M        40   1880321        53  724842
# 3988585  3661917           M        40   4710590        12  125041
# 3988586  3661917           M        40   1586846        86  610681
#
#                                      PD_ADD_NM  PD_BRA_NM PD_BUY_AM PD_BUY_CT  \
# 100                      선택:옴니360쿨에어_펄그레이 / 1개     에르고베이비   280,000         1
# 101                                         1개        비박스    16,500         1
# 102                                         1개        정관장   100,000         1
# 103                                         2개       정관장.    75,000         2
# 104                        색상:아이보리|사이즈:XS / 1개      게스(진)    10,000         1
# 105                         색상:화이트|사이즈:XS / 1개      게스(진)    11,900         1
# 106                          색상:레드|사이즈:XS / 1개      게스(진)    19,000         1
# 107                                         2개       세이어스    10,930         2
# 108                                         4개       생각투자    16,660         4
# 109                                         1개       루치펠로    39,900         1
# 110                                         1개       루치펠로    65,000         1
# 111                                         4개       루치펠로    35,900         4
# 112                           색상:블랙|사이즈:F / 1개         비키    39,000         1
# 113           스타일번호:890372-010|사이즈:070(M) / 1개    나이키(의류)    40,000         1
# 114              상품명:LCWN826M51블랙|사이즈:270 / 1개        엘칸토    44,000         1
# 115                          색상:블랙|사이즈:77 / 1개   비비드시크릿가너    53,000         1
# 116                 사이즈:옵션10._GU4020D_26G / 1개   게스(선글라스)    55,370         1
# 117                       색상:2 핑크|사이즈:245 / 1개     게스(구두)    79,000         1
# 118                         색상:블랙|사이즈:245 / 1개    소다(여성화)   109,000         1
# 119                                         1개        러브캣   190,000         1
# 120                                         1개        러브캣   190,000         1
# 121                                         1개        러브캣   190,000         1
# 122                                         1개        유세린    40,800         1
# 123                                         1개        유세린    41,600         1
# 124                                         1개   오트리푸드빌리지    36,900         1
# 125                                         1개   오트리푸드빌리지    36,900         1
# 126                          색상:LI|사이즈:80 / 1개     레노마수영복    69,000         1
# 127                        색상:네이비|사이즈:13호 / 1개  아이스샌드(아동)    35,000         1
# 128                         색상:베이지|사이즈:55 / 1개      나이스클랍   149,500         1
# 129                       색상:베이지BE|사이즈:55 / 1개      나이스클랍   149,500         1
# ...                                        ...        ...       ...       ...
# 3988557       향선택1:핑크그레이프후르츠|향선택2:그린애플&바질 / 1개       에티튜드    14,800         1
# 3988558                    사이즈:XL 1팩(44p) / 1개        메리즈    17,500         1
# 3988559                 직접입력1:21호 내추럴톤업커버 / 1개        AHC    27,200         1
# 3988560                 색상:아이보리(02)|사이즈:S / 1개        버커루    11,700         1
# 3988561               색상:멜란지그레이(13)|사이즈:M / 1개        버커루    11,700         1
# 3988562                                     1개       정관장.    19,800         1
# 3988563                색상:챠콜그레이|사이즈:95(M) / 1개      게스(진)    27,200         1
# 3988564               스타일:JPST-439|사이즈:24 / 1개        비고스    31,300         1
# 3988565              스타일:JPCI-3536|사이즈:24 / 1개        비고스    31,300         1
# 3988566              스타일:JPCI-3536|사이즈:24 / 1개        비고스    31,300         1
# 3988567                      색상:카키|Size:S / 1개      에잇세컨즈    39,900         1
# 3988568                       색상:블루|사이즈:S / 1개     엘리든플레이    76,800         1
# 3988569                    색상:블랙|사이즈:FREE / 1개     엘리든플레이    70,800         1
# 3988576  홍삼/인삼가공식품           홍삼액
# 3988577     여아의류하의         여아레깅스
# 3988578     여아의류하의         여아레깅스
# 3988579     여아의류하의         여아레깅스
# 3988580     여아의류하의         여아레깅스
# 3988581  여성일반스포츠의류    여성스포츠티셔츠/탑
# 3988582  여성일반스포츠의류     여성일반스포츠바지
# 3988583  남성일반스포츠의류      남성스포츠티셔츠
# 3988584       피트니스        피트니스용품
# 3988585       스킨케어          미용비누
# 3988586     여성위생용품           생리대
#
# [3988487 rows x 14 columns]

# %%
#Femaie
Custom_Product_Master['CLNT_GENDER'] == 'F'
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
# 6           True
# 7           True
# 8           True
# 9           True
# 10          True
# 11          True
# 12          True
# 13          True
# 14          True
# 15          True
# 16          True
# 17          True
# 18          True
# 19          True
# 20          True
# 21          True
# 22          True
# 23          True
# 24          True
# 25          True
# 26          True
# 27          True
# 28          True
# 29          True
#            ...
# 3988557     True
# 3988558     True
# 3988559     True
# 3988560     True
# 3988561     True
# 3988562     True
# 3988563     True
# 3988564     True
# 3988565     True
# 3988566     True
# 3988567     True
# 3988568     True
# 3988569     True
# 3988570     True
# 3988571     True
# 3988572     True
# 3988573    False
# 3988574    False
# 3988575     True
# 3988576     True
# 3988577     True
# 3988578     True
# 3988579     True
# 3988580     True
# 3988581    False
# 3988582    False
# 3988583    False
# 3988584    False
# 3988585    False
# 3988586    False
# Name: CLNT_GENDER, Length: 3988587, dtype: bool

# %%
Custom_Product_Master.shape
# Out:
# (3988587, 14)

# %%
CPM_F = Custom_Product_Master[Custom_Product_Master['CLNT_GENDER'] == 'F']
CPM_F.shape
# Out:
# (3491522, 14)

# %%
CPM_F = CPM_F.drop(CPM_F.columns[[0,3]], axis=1)

# %%
CPM_F.head()
# Out:
#   CLNT_GENDER  CLNT_AGE  HITS_SEQ    PD_C                      PD_ADD_NM  \
# 0           F        30        45  357970                             1개
# 1           F        30        27  357970                             1개
# 2           F        40        35   81976   색상:버건디(90)|사이즈:S(90/66) / 1개
# 3           F        40        35   81976  색상:아이보리(41)|사이즈:S(90/66) / 1개
# 4           F        40        35   81976  색상:D/그린(04)|사이즈:S(90/66) / 1개
#
#     PD_BRA_NM PD_BUY_AM PD_BUY_CT  \
# 0  에스까다(선글라스)   130,000         1
# 1  에스까다(선글라스)   130,000         1
# 2          유닛    69,000         1
# 3          유닛    69,000         1
# 4          유닛    69,000         1
#
#                                                PD_NM CLAC1_NM CLAC2_NM  \
# 0                                SES937G 531X SES937     패션잡화  안경/선글라스
# 1                                SES937G 531X SES937     패션잡화  안경/선글라스
# 2  [UFC4-KT42N]캐시미어100프로 기본 터틀넥 니트 스웨터 - L/블루(15)...     여성의류   여성의류상의
# 3  [UFC4-KT42N]캐시미어100프로 기본 터틀넥 니트 스웨터 - L/블루(15)...     여성의류   여성의류상의
# 4  [UFC4-KT42N]캐시미어100프로 기본 터틀넥 니트 스웨터 - L/블루(15)...     여성의류   여성의류상의
#
#     CLAC3_NM
# 0        안경테
# 1        안경테
# 2  여성스웨터/풀오버
# 3  여성스웨터/풀오버
# 4  여성스웨터/풀오버
