# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from pathlib import Path
import os

# %%
#Product 테이블 
#데이터가져오기
Product = pd.read_csv("C:/Users/lsh93/Desktop/data/Product.csv")
# Out:
# C:\Users\lsh93\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#데이터보기
Product['CLNT_ID'][1]
# Out:
# 4140076

# %%
Product['SESS_ID'][1]
# Out:
# 10189797

# %%
#Search1 테이블
#데이터가져오기
Search1 = pd.read_csv("C:/Users/lsh93/Desktop/data/Search1.csv")

# %%
#Search2 테이블
Search2 = pd.read_csv("C:/Users/lsh93/Desktop/data/Search2.csv")

# %%
#Custom
Custom = pd.read_csv("C:/Users/lsh93/Desktop/data/Custom.csv")

# %%
#Session
Session = pd.read_csv("C:/Users/lsh93/Desktop/data/Session.csv")

# %%
#상품분류
Master = pd.read_csv("C:/Users/lsh93/Desktop/data/Master.csv")

# %%
#Custom - Product
Custom_Product = pd.merge(Custom,Product)

# %%
Custom
# Out:
#         CLNT_ID CLNT_GENDER  CLNT_AGE
# 0       4830726           F        30
# 1       4830874           F        40
# 2       4830975           F        30
# 3       4831275           F        30
# 4       4825325           F        30
# 5       4825382           F        40
# 6       4825797           F        40
# 7       4825908           F        30
# 8       4825961           F        30
# 9       4840532           M        40
# 10      4840825           F        10
# 11      4843304           F        30
# 12      4843591           F        30
# 13      4843997           F        30
# 14      4846369           F        30
# 15      4846380           F        20
# 16      4846440           M        40
# 17      4846511           M        40
# 18      4846738           F        20
# 19      4846869           F        30
# 20      4847147           F        20
# 21      4839353           F        30
# 22      4839427           F        30
# 23      4839489           F        40
# ...

# %%
Custom_Product
# Out:
#          CLNT_ID CLNT_GENDER  CLNT_AGE   SESS_ID  HITS_SEQ    PD_C  \
# 0        4830726           F        30   2546785        45  357970
# 1        4830726           F        30   2546785        27  357970
# 2        4830874           F        40   1456881        35   81976
# 3        4830874           F        40   1456881        35   81976
# 4        4830874           F        40   1456881        35   81976
# 5        4830874           F        40   1456881        35   81976
# 6        4830975           F        30  10583060        64  782816
# 7        4830975           F        30  10578803         2  782816
# 8        4831275           F        30   3856961        32  621467
# 9        4831275           F        30   7384688        22  225731
# 10       4825325           F        30   2943346        80   70116
# 11       4825325           F        30    882378        10  382752
# 12       4825325           F        30   3606834       277  332488
# ...

# %%
Custom_Product.to_csv("C:/Users/lsh93/Desktop/data/Custom_Product.csv", encoding="UTF-8")

# %%
#Custom - Search1
Custom_Search1 = pd.merge(Custom,Search1)

# %%
Custom_Search1
# Out:
#          CLNT_ID CLNT_GENDER  CLNT_AGE   SESS_ID         KWD_NM  SEARCH_CNT
# 0        4830726           F        30   2546785      에스까다 선글라스           1
# 1        4830726           F        30   2546785       끌로에 선글라스           1
# 2        4830726           F        30   2546785      페라가모 선글라스           1
# 3        4830726           F        30   2546785        톰포드선글라스           1
# 4        4825325           F        30   3365352     타미힐피거키즈티셔츠           1
# 5        4825325           F        30   3606834        닥스키즈원피스           1
# 6        4825325           F        30   3365352         블루독원피스           1
# 7        4825325           F        30   2943346          밍크뮤패딩           1
# 8        4825325           F        30   3606834        타미힐피거키즈           3
# 9        4825325           F        30   3606834     타미힐피거키즈원피스           1
# 10       4825325           F        30   3606834      타미힐피거키즈셔츠           1
# ...

# %%
Custom_Search1.to_csv("C:/Users/lsh93/Desktop/data/Custom_Search1.csv", encoding="UTF-8")

# %%
#Custom - Session
Custom_Session = pd.merge(Custom,Session)

# %%
Custom_Session
# Out:
#          CLNT_ID CLNT_GENDER  CLNT_AGE   SESS_ID  SESS_SEQ   SESS_DT  \
# 0        4830726           F        30   2546785        32  20180818
# 1        4830874           F        40   1456881        18  20180906
# 2        4830975           F        30  10578803         5  20180407
# 3        4830975           F        30  10583060         4  20180407
# 4        4831275           F        30   3856961        29  20180727
# 5        4831275           F        30   7384688        20  20180530
# 6        4825325           F        30   6820838        85  20180608
# 7        4825325           F        30    882378       166  20180915
# 8        4825325           F        30   3365352       106  20180804
# 9        4825325           F        30     83428       186  20180929
# 10       4825325           F        30   3606834       103  20180731
# 11       4825325           F        30   6895996        83  20180607
# 12       4825325           F        30   4020792        96  20180724
# ...

# %%
Custom_Session.to_csv("C:/Users/lsh93/Desktop/data/Custom_Session.csv", encoding="UTF-8")

# %%
Product_Master = pd.merge(Product, Master)

# %%
Product_Master
# Out:
#          CLNT_ID   SESS_ID  HITS_SEQ    PD_C                       PD_ADD_NM  \
# 0        4139680   7605037        12  642112                         색상:워터멜론
# 1        4350334   2023661        77  642112                      색상:엔젤 / 1개
# 2        5172356   4714565        47  642112                          색상:카바나
# 3        5444959   6843465        24  642112                    색상:워터멜론 / 1개
# 4        5461276   7896792        53  642112                    색상:워터멜론 / 1개
# 5        5482254   7577611        40  642112                     색상:라일락 / 1개
# 6        5482254   7577611        40  642112                    색상:워터멜론 / 1개
# 7        3883028    987588         8  642112                          색상:카바나
# 8        5153670   8154313        24  642112                      색상:루비 / 1개
# 9        5325474   2566731        21  642112                      색상:루비 / 1개
# 10       5325878   8380603        18  642112                     색상:카바나 / 1개
# ...

# %%
Custom_Product_Master = pd.merge(Custom,Product_Master)
Custom_Product_Master_Search1 = pd.merge(Custom_Product_Master, Search1)

# %%
Custom_Product_Master_Search1
# Out:
#          CLNT_ID CLNT_GENDER  CLNT_AGE   SESS_ID  HITS_SEQ    PD_C  \
# 0        4830726           F        30   2546785        45  357970
# 1        4830726           F        30   2546785        45  357970
# 2        4830726           F        30   2546785        45  357970
# 3        4830726           F        30   2546785        45  357970
# 4        4830726           F        30   2546785        27  357970
# 5        4830726           F        30   2546785        27  357970
# 6        4830726           F        30   2546785        27  357970
# 7        4830726           F        30   2546785        27  357970
# 8        4825325           F        30   2943346        80   70087
# 9        4825325           F        30   2943346        80   70087
# 10       4825325           F        30   2943346        80   70087
# 11       4825325           F        30   2943346        80   70116
# 12       4825325           F        30   2943346        80   70116
# ...

# %%
#상품코드, client, 상품코드, 검색어, 상품군 
data2 = Custom_Product_Master_Search1.drop(Custom_Product_Master_Search1.columns[[1, 2, 3, 4, 5, 6,9]], axis=1)

# %%
data2
# Out:
#          CLNT_ID   PD_BRA_NM PD_BUY_AM  \
# 0        4830726  에스까다(선글라스)   130,000
# 1        4830726  에스까다(선글라스)   130,000
# 2        4830726  에스까다(선글라스)   130,000
# 3        4830726  에스까다(선글라스)   130,000
# 4        4830726  에스까다(선글라스)   130,000
# 5        4830726  에스까다(선글라스)   130,000
# 6        4830726  에스까다(선글라스)   130,000
# 7        4830726  에스까다(선글라스)   130,000
# 8        4825325         밍크뮤    49,000
# 9        4825325         밍크뮤    49,000
# 10       4825325         밍크뮤    49,000
# 11       4825325         밍크뮤    43,000
# 12       4825325         밍크뮤    43,000
# 13       4825325         밍크뮤    43,000
# 14       4825325         밍크뮤    48,300
# 15       4825325         밍크뮤    48,300
# 16       4825325         밍크뮤    48,300
# 17       4825325         밍크뮤    48,300
# 18       4825325         밍크뮤    48,300
# 19       4825325         밍크뮤    48,300
# 20       4825325         밍크뮤    48,300
# 21       4825325         밍크뮤    48,300
# 22       4825325         밍크뮤    48,300
# ...

# %%
data2.to_csv("C:/Users/lsh93/Desktop/data/data2.csv", encoding="UTF-8")
