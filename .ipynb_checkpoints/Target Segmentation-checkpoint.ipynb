# %% [markdown]
# # Trend Predicting
#
# * **Problem**: Trend Predicting based on user behaviors
# * **Description**:
#   * Create online preference index for each major product group
#   * Predict demand trends and draw insights by product group
#   * Suggest new service from 1), 2)
# * **Dataset**: ? non-numeric column, and ? numeric columns
#   * ? : ?
#   * Non-numeric columns:
#     * 16 non-numeric columns : ?
#   * Numeric columns:
#     * 104 numeric columns : ?

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path
import os

# %% [markdown]
# # Load Data
#
# * 'custom.csv'
# * 'search1.csv'
# * 'search2.csv'
# * 'master.csv'
# * 'session.csv'
# * 'product.csv'

# %%
path = Path().resolve().parents[0]
product = pd.read_csv(os.path.join(path, 'Dataset', 'Product.csv'))
search1 = pd.read_csv(os.path.join(path, 'Dataset', 'Search1.csv'))
search2 = pd.read_csv(os.path.join(path, 'Dataset', 'Search2.csv'))
custom = pd.read_csv(os.path.join(path, 'Dataset', 'Custom.csv'))
session = pd.read_csv(os.path.join(path, 'Dataset', 'Session.csv'))
master = pd.read_csv(os.path.join(path, 'Dataset', 'Master.csv'))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print('product shape : ', product.shape)
print('search1 shape : ', search1.shape)
print('search2 shape : ', search2.shape)
print('custom shape : ', custom.shape)
print('session shape : ', session.shape)
print('master shape : ', master.shape)
# Out:
# product shape :  (5024906, 8)
# search1 shape :  (2884943, 4)
# search2 shape :  (8051172, 3)
# custom shape :  (671679, 3)
# session shape :  (2712907, 9)
# master shape :  (847652, 5)

# %%
product.head()
# Out:
#    CLNT_ID   SESS_ID  HITS_SEQ    PD_C                         PD_ADD_NM  \
# 0  4139680   7605037        12  642112                           색상:워터멜론
# 1  4140076  10189797        13  570603  색상:BLK0_(BLK0)BLACK|사이즈:120 / 2개
# 2  4142395   6158159        85  179538                         (not set)
# 3  4144914   7935714        12  554336      색상:블랙|사이즈:160cm(12~13세) / 1개
# 4  4144917   6406509        78  190306                                5개
#
#   PD_BRA_NM PD_BUY_AM PD_BUY_CT
# 0   [바비브라운]    39,000         1
# 1       데상트    39,000         2
# 2     [아베다]    39,000         1
# 3   아디다스 키즈    39,000         1
# 4      데코르테    39,000         5

# %%
search1.head()
# Out:
#    CLNT_ID  SESS_ID     KWD_NM  SEARCH_CNT
# 0  5607714  7112876   빌리프 아이크림           6
# 1  5607714  4090791  프리메라 마스크팩           3
# 2  5607714  4090791      여성청결제           1
# 3  5612428  1876482       명품가방           1
# 4  5612428   658123  콩순이 아이스크림           1

# %%
search2.head()
# Out:
#     SESS_DT     KWD_NM SEARCH_CNT
# 0  20180407      닥스원피스          8
# 1  20180407  닥터지 브라이트닝          1
# 2  20180407     달팡 인트랄          2
# 3  20180407        대상트          1
# 4  20180407       더블유닷          6

# %%
custom.head()
# Out:
#    CLNT_ID CLNT_GENDER  CLNT_AGE
# 0  4830726           F        30
# 1  4830874           F        40
# 2  4830975           F        30
# 3  4831275           F        30
# 4  4825325           F        30

# %%
session.head()
# Out:
#    CLNT_ID   SESS_ID  SESS_SEQ   SESS_DT  TOT_PAG_VIEW_CT TOT_SESS_HR_V  \
# 0  5873599   8641867         9  20180509             82.0         1,890
# 1  5873599   6616320        21  20180611            105.0         1,604
# 2  5873599   5886172        40  20180624             41.0           632
# 3  5873884   1050889        15  20180913            160.0         1,035
# 4  5874461  10298270         5  20180412             13.0           298
#
#   DVC_CTG_NM       ZON_NM  CITY_NM
# 0     mobile      Daejeon  Daejeon
# 1     mobile        Busan    Busan
# 2     mobile      Daejeon  Daejeon
# 3     mobile  Gyeonggi-do   Anyang
# 4     mobile        Seoul    Seoul

# %%
master.head()
# Out:
#     PD_C                                              PD_NM   CLAC1_NM  \
# 0  64382   언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]      스포츠패션
# 1  62282                         여자 플라워덧신 2족선물세트 17403-2set  속옷/양말/홈웨어
# 2  61729                       88A2933253배트맨스웨트티 - 블랙 / 130      유아동의류
# 3  61537            닥터마틴 아드리안 블랙, 체리레드 - 02_체리레드 / 250mm(6)       패션잡화
# 4  58820  여성 그레이 스트라이프 퍼프 소매 블라우스 (128865YQ33) - 회색(앤틱실버...       남성의류
#
#     CLAC2_NM  CLAC3_NM
# 0  남성일반스포츠의류  남성스포츠티셔츠
# 1      여성양말류    여성일반양말
# 2     유아의류상의  영유아티셔츠/탑
# 3        남성화      남성부츠
# 4     남성의류상의    남성남방셔츠

# %% [markdown]
# # Merge Data
# 1) Merge product purchase data to see features which is expected to affect on purchase of client bought given product group, not individual product
#
# - Merge following csv files
#     * Product.csv : CLNT_ID, SESS_ID(Brdige), PD_C(Bridge), PD_BUY_CT, PD_BUY_AM
#     * Master.csv : PD_C(Bridge), CLAC1_NM, CLAC2_NM, CLAC3_NM
#     * Session.csv : SESS_ID(Bridge), SESS_DT, DVC_CTG_NM, ZON_NM, CITY_NM
#     * Custom.csv : CLNT_ID, CLNT_GENDER, CLNT_AGE
#
#
# - To get data below
#
#
# - Client Information
#     * CLNT_ID : Client ID (Primary Key)
#     * CLNT_GENDER : Client Gender
#     * CLNT_AGE : Client Age
#     * DVC_CTG_NM : Client Device
#     * ZON_NM : Client Location (briefly)
#     * CITY_NM : Client Location (in detail)
#
# - Purchase Information
#     * SESS_DT : Session Date
#     * PD_BUY_CT : Number of product purchased
#     * PD_BUY_AM : Price of product purchased
#
# - Product Information
#     * CLAC1_NM : Product group (largest)
#     * CLAC2_NM : Product group (moderate)
#     * CLAC3_NM : Product group (smallest)

# %%
merge1 = pd.merge(product, master)
merge1.head()
# Out:
#    CLNT_ID  SESS_ID  HITS_SEQ    PD_C     PD_ADD_NM PD_BRA_NM PD_BUY_AM  \
# 0  4139680  7605037        12  642112       색상:워터멜론   [바비브라운]    39,000
# 1  4350334  2023661        77  642112    색상:엔젤 / 1개     바비브라운    39,000
# 2  5172356  4714565        47  642112        색상:카바나   [바비브라운]    39,000
# 3  5444959  6843465        24  642112  색상:워터멜론 / 1개     바비브라운    39,000
# 4  5461276  7896792        53  642112  색상:워터멜론 / 1개     바비브라운    39,000
#
#   PD_BUY_CT          PD_NM  CLAC1_NM CLAC2_NM       CLAC3_NM
# 0         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터
# 1         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터
# 2         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터
# 3         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터
# 4         1  크러쉬드 립칼라 - 플럼  화장품/뷰티케어     메이크업  블러셔/쉐이딩/하이라이터

# %%
merge1 = merge1.drop(['HITS_SEQ','PD_C', 'PD_ADD_NM', 'PD_BRA_NM', 'PD_NM'], axis=1)
merge1.head()

# %%
merge2 = pd.merge(merge1, session)
merge2.head()

# %%
merge2 = merge2.drop(['SESS_ID', 'SESS_SEQ','TOT_PAG_VIEW_CT', 'TOT_SESS_HR_V'], axis=1)
merge2.head()

# %%
merge3 = pd.merge(merge2, custom)
merge3.head()

# %% [markdown]
# ## Explore Data (3)
# * Cluster wholesale merchant
# * It seems there are wholesale merchants within clients, thus we'd like to cluster them in order to see with/without them how data distribution changes
#
# 1) Merge Data for clustering
# * Features expected to help us distinguish wholesale merchants
#     * dd

# %%
merge3.head()

# %%
clnt_id = merge3['CLNT_ID'].unique()
clac1_nm = merge3['CLAC1_NM'].unique()
clac2_nm = merge3['CLAC2_NM'].unique()
clac3_nm = merge3['CLAC3_NM'].unique()
print(clnt_id.shape)
print(clac1_nm.shape)
print(clac2_nm.shape)
print(clac3_nm.shape)

# %%
for idx, clnt_idx in enumerate(clnt_id) :
    print(m)

# %% [markdown]
# ### 2) KMeans Clustering

# %%
from sklearn.cluster import KMeans
import seaborn as sns

# KMeans

data_for_clustering = heavy_light_users.values.reshape(-1, 1)
km = KMeans(n_clusters=4)
km.fit(data_for_clustering)
labels = km.labels_
results = pd.DataFrame([heavy_light_users.index,heavy_light_users,labels]).T
print(results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-48540ab8f1a5> in <module>
#       8 km.fit(data_for_clustering)
#       9 labels = km.labels_
# ---> 10 results = pd.DataFrame([heavy_light_users.index,heavy_light_users,labels]).T.columns(['a', 'b','c'])
#      11 print(results)
#
# TypeError: 'RangeIndex' object is not callable

# %% [markdown]
# 2)
